# %%
import SimpleITK as sitk
import dltk
import numpy as np
import os
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import dicom
import os
import scipy.ndimage
import matplotlib.pyplot as plt
from skimage import measure, morphology
import cv2
from scipy.ndimage import zoom

# %%
INPUT_FOLDER = 'TrainingSet_1_of_2/'
patients = os.listdir(INPUT_FOLDER)

# %%
pts = []

# %%
for ps in os.listdir(INPUT_FOLDER):
    print("Image Name", ps)
    t1 = sitk.ReadImage(INPUT_FOLDER+ps)
    t2 = sitk.GetArrayFromImage(t1)
    pts.append(t2)
# Out:
# Image Name CTR_TRN_001.nii.gz
# Image Name CTR_TRN_002.nii.gz
# Image Name CTR_TRN_003.nii.gz
# Image Name CTR_TRN_004.nii.gz
# Image Name CTR_TRN_005.nii.gz
# Image Name CTR_TRN_006.nii.gz
# Image Name CTR_TRN_007.nii.gz
# Image Name CTR_TRN_008.nii.gz
# Image Name CTR_TRN_009.nii.gz
# Image Name CTR_TRN_010.nii.gz
# Image Name CTR_TRN_011.nii.gz
# Image Name CTR_TRN_012.nii.gz
# Image Name CTR_TRN_013.nii.gz
# Image Name CTR_TRN_014.nii.gz
# Image Name CTR_TRN_015.nii.gz
# Image Name CTR_TRN_016.nii.gz
# Image Name CTR_TRN_017.nii.gz
# Image Name CTR_TRN_018.nii.gz
# Image Name CTR_TRN_019.nii.gz
# Image Name CTR_TRN_020.nii.gz
# Image Name CTR_TRN_021.nii.gz
# Image Name CTR_TRN_022.nii.gz
# Image Name CTR_TRN_023.nii.gz
# Image Name CTR_TRN_024.nii.gz
# Image Name CTR_TRN_025.nii.gz
# Image Name CTR_TRN_026.nii.gz
# Image Name CTR_TRN_027.nii.gz
# Image Name CTR_TRN_028.nii.gz
# Image Name CTR_TRN_029.nii.gz
# Image Name CTR_TRN_030.nii.gz
# Image Name CTR_TRN_031.nii.gz
# Image Name CTR_TRN_032.nii.gz
# Image Name CTR_TRN_033.nii.gz
# Image Name CTR_TRN_034.nii.gz
# Image Name CTR_TRN_035.nii.gz
# Image Name CTR_TRN_036.nii.gz
# Image Name CTR_TRN_037.nii.gz
# Image Name CTR_TRN_038.nii.gz
# Image Name CTR_TRN_039.nii.gz
# Image Name CTR_TRN_040.nii.gz
# Image Name CTR_TRN_041.nii.gz
# Image Name CTR_TRN_042.nii.gz
# Image Name CTR_TRN_043.nii.gz
# Image Name CTR_TRN_044.nii.gz
# Image Name CTR_TRN_045.nii.gz
# Image Name CTR_TRN_046.nii.gz
# Image Name CTR_TRN_047.nii.gz
# Image Name CTR_TRN_048.nii.gz
# Image Name CTR_TRN_049.nii.gz
# Image Name CTR_TRN_050.nii.gz
# Image Name CTR_TRN_051.nii.gz
# Image Name CTR_TRN_052.nii.gz
# Image Name CTR_TRN_053.nii.gz
# Image Name CTR_TRN_054.nii.gz
# Image Name CTR_TRN_055.nii.gz
# Image Name CTR_TRN_056.nii.gz
# Image Name CTR_TRN_057.nii.gz
# Image Name CTR_TRN_058.nii.gz
# Image Name CTR_TRN_059.nii.gz
# Image Name CTR_TRN_060.nii.gz
# Image Name CTR_TRN_061.nii.gz
# Image Name CTR_TRN_062.nii.gz
# Image Name CTR_TRN_063.nii.gz
# Image Name CTR_TRN_064.nii.gz
# Image Name CTR_TRN_065.nii.gz
# Image Name CTR_TRN_066.nii.gz
# Image Name CTR_TRN_067.nii.gz
# Image Name CTR_TRN_068.nii.gz
# Image Name CTR_TRN_069.nii.gz
# Image Name CTR_TRN_070.nii.gz
# Image Name CTR_TRN_071.nii.gz
# Image Name CTR_TRN_072.nii.gz
# Image Name CTR_TRN_073.nii.gz
# Image Name CTR_TRN_074.nii.gz
# Image Name CTR_TRN_075.nii.gz
# Image Name CTR_TRN_076.nii.gz
# Image Name CTR_TRN_077.nii.gz
# Image Name CTR_TRN_078.nii.gz
# Image Name CTR_TRN_079.nii.gz
# Image Name CTR_TRN_080.nii.gz
# Image Name CTR_TRN_081.nii.gz
# Image Name CTR_TRN_082.nii.gz
# Image Name CTR_TRN_083.nii.gz
# Image Name CTR_TRN_084.nii.gz
# Image Name CTR_TRN_085.nii.gz
# Image Name CTR_TRN_086.nii.gz
# Image Name CTR_TRN_087.nii.gz
# Image Name CTR_TRN_088.nii.gz
# Image Name CTR_TRN_089.nii.gz
# Image Name CTR_TRN_090.nii.gz
# Image Name CTR_TRN_091.nii.gz
# Image Name CTR_TRN_092.nii.gz
# Image Name CTR_TRN_093.nii.gz
# Image Name CTR_TRN_094.nii.gz
# Image Name CTR_TRN_095.nii.gz
# Image Name CTR_TRN_096.nii.gz
# Image Name CTR_TRN_097.nii.gz
# Image Name CTR_TRN_098.nii.gz
# Image Name CTR_TRN_099.nii.gz
# Image Name CTR_TRN_100.nii.gz
# Image Name CTR_TRN_101.nii.gz
# Image Name CTR_TRN_102.nii.gz
# Image Name CTR_TRN_103.nii.gz
# Image Name CTR_TRN_104.nii.gz
# Image Name CTR_TRN_105.nii.gz
# Image Name CTR_TRN_106.nii.gz
# Image Name CTR_TRN_107.nii.gz
# Image Name CTR_TRN_108.nii.gz
# Image Name CTR_TRN_109.nii.gz
# Image Name CTR_TRN_110.nii.gz
# Image Name CTR_TRN_111.nii.gz
# Image Name CTR_TRN_112.nii.gz
# Image Name CTR_TRN_113.nii.gz
# Image Name CTR_TRN_114.nii.gz
# Image Name CTR_TRN_115.nii.gz
# Image Name CTR_TRN_116.nii.gz
# Image Name CTR_TRN_117.nii.gz
# Image Name CTR_TRN_118.nii.gz
# Image Name CTR_TRN_119.nii.gz
# Image Name CTR_TRN_120.nii.gz
# Image Name CTR_TRN_121.nii.gz
# Image Name CTR_TRN_122.nii.gz
# Image Name CTR_TRN_123.nii.gz
# Image Name CTR_TRN_124.nii.gz
# Image Name CTR_TRN_125.nii.gz
# Image Name CTR_TRN_126.nii.gz
# Image Name CTR_TRN_127.nii.gz
# Image Name CTR_TRN_128.nii.gz
# Image Name CTR_TRN_129.nii.gz
# Image Name CTR_TRN_130.nii.gz
# Image Name CTR_TRN_131.nii.gz
# Image Name CTR_TRN_132.nii.gz
# Image Name CTR_TRN_133.nii.gz
# Image Name CTR_TRN_134.nii.gz
# Image Name CTR_TRN_135.nii.gz
# Image Name CTR_TRN_136.nii.gz
# Image Name CTR_TRN_137.nii.gz
# Image Name CTR_TRN_138.nii.gz
# Image Name CTR_TRN_139.nii.gz
# Image Name CTR_TRN_140.nii.gz
# Image Name CTR_TRN_141.nii.gz
# Image Name CTR_TRN_142.nii.gz
# Image Name CTR_TRN_143.nii.gz
# Image Name CTR_TRN_144.nii.gz
# Image Name CTR_TRN_145.nii.gz
# Image Name CTR_TRN_146.nii.gz
# Image Name CTR_TRN_147.nii.gz
# Image Name CTR_TRN_148.nii.gz
# Image Name CTR_TRN_149.nii.gz
# Image Name CTR_TRN_150.nii.gz
# Image Name CTR_TRN_151.nii.gz
# Image Name CTR_TRN_152.nii.gz
# Image Name CTR_TRN_153.nii.gz
# Image Name CTR_TRN_154.nii.gz
# Image Name CTR_TRN_155.nii.gz
# Image Name CTR_TRN_156.nii.gz
# Image Name CTR_TRN_157.nii.gz
# Image Name CTR_TRN_158.nii.gz
# Image Name CTR_TRN_159.nii.gz
# Image Name CTR_TRN_160.nii.gz
# Image Name CTR_TRN_161.nii.gz
# Image Name CTR_TRN_162.nii.gz
# Image Name CTR_TRN_163.nii.gz
# Image Name CTR_TRN_164.nii.gz
# Image Name CTR_TRN_165.nii.gz
# Image Name CTR_TRN_166.nii.gz
# Image Name CTR_TRN_167.nii.gz
# Image Name CTR_TRN_168.nii.gz
# Image Name CTR_TRN_169.nii.gz
# Image Name CTR_TRN_170.nii.gz
# Image Name CTR_TRN_171.nii.gz
# Image Name CTR_TRN_172.nii.gz
# Image Name CTR_TRN_173.nii.gz
# Image Name CTR_TRN_174.nii.gz
# Image Name CTR_TRN_175.nii.gz
# Image Name CTR_TRN_176.nii.gz
# Image Name CTR_TRN_177.nii.gz
# Image Name CTR_TRN_178.nii.gz
# Image Name CTR_TRN_179.nii.gz
# Image Name CTR_TRN_180.nii.gz
# Image Name CTR_TRN_181.nii.gz
# Image Name CTR_TRN_182.nii.gz
# Image Name CTR_TRN_183.nii.gz
# Image Name CTR_TRN_184.nii.gz
# Image Name CTR_TRN_185.nii.gz
# Image Name CTR_TRN_186.nii.gz
# Image Name CTR_TRN_187.nii.gz
# Image Name CTR_TRN_188.nii.gz
# Image Name CTR_TRN_189.nii.gz
# Image Name CTR_TRN_190.nii.gz
# Image Name CTR_TRN_191.nii.gz
# Image Name CTR_TRN_192.nii.gz
# Image Name CTR_TRN_193.nii.gz
# Image Name CTR_TRN_194.nii.gz
# Image Name CTR_TRN_195.nii.gz
# Image Name CTR_TRN_196.nii.gz
# Image Name CTR_TRN_197.nii.gz
# Image Name CTR_TRN_198.nii.gz
# Image Name CTR_TRN_199.nii.gz
# Image Name CTR_TRN_200.nii.gz
# Image Name CTR_TRN_201.nii.gz
# Image Name CTR_TRN_202.nii.gz
# Image Name CTR_TRN_203.nii.gz
# Image Name CTR_TRN_204.nii.gz
# Image Name CTR_TRN_205.nii.gz
# Image Name CTR_TRN_206.nii.gz
# Image Name CTR_TRN_207.nii.gz
# Image Name CTR_TRN_208.nii.gz
# Image Name CTR_TRN_209.nii.gz
# Image Name CTR_TRN_210.nii.gz
# Image Name CTR_TRN_211.nii.gz
# Image Name CTR_TRN_212.nii.gz
# Image Name CTR_TRN_213.nii.gz
# Image Name CTR_TRN_214.nii.gz
# Image Name CTR_TRN_215.nii.gz
# Image Name CTR_TRN_216.nii.gz
# Image Name CTR_TRN_217.nii.gz
# Image Name CTR_TRN_218.nii.gz

# %%
len(pts)
# Out:
# 218

# %%
w, h = 128, 128
def rs_img(img):
    '''W and H is 128 now
    '''
    img = np.transpose(img)
    flatten = [cv2.resize(img[:,:,i], (w, h), interpolation=cv2.INTER_CUBIC) for i in range(img.shape[-1])]
    img = np.array(np.dstack(flatten)) 
    return img

# %%
def change_depth(img):
    desired_depth = 64
    current_depth = img.shape[-1]
    depth = current_depth / desired_depth
    depth_factor = 1 / depth
    img_new = zoom(img, (1, 1, depth_factor), mode='nearest')
    return img_new

# %%
dep = []

# %%
for pt in pts:
    img = rs_img(pt)
    img = change_depth(img)
    print(img.shape)
    dep.append(img)
# Out:
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# C:\Users\Aiman\Anaconda3\envs\sticker\lib\site-packages\scipy\ndimage\interpolation.py:605: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)
# (128, 128, 64)

# %% [markdown]
# # Visualize

# %%
def show_images(images, cols = 1, titles = None, save_fig = "default"):
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    #fig.set_title("Samples of infected red blood cells")
    
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        plt.axis("off")
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.savefig('{}'.format(save_fig), dpi=10)
    plt.show()

# %%
image_number = 10
img_3d = dep[1]
print(img_3d.shape)
# Out:
# (128, 128, 32)

# %%
images = []

# get individual slices from 3d image
for i in range(img_3d.shape[-1]):
    images.append(img_3d[:,:,i])
    
images = np.array(images)
print(len(images))
# Out:
# 32

# %%
show_images(images[:16], cols = 4, titles = None, save_fig="ct-scans")

# %%
dep = np.array(dep)
npy = np.save('dep_64.npy', dep)
